# %% [markdown]
# # Лабароторная работа 3

# %% [markdown]
# # Анимация движения секущей прямой к заданной линии на плоскости

# %% [markdown]
# Федоренко Алексей Жанович, 13.03.2025

# %%
from matplotlib.animation import FuncAnimation

# %% [markdown]
# ## Задание 3.1

# %% [markdown]
# ### 3.1A
# $\color{red}\text{Создайте анимацию}$ построения графика некоторой явно заданной
# аналитической функции $y=y(x)$ по значениям $x$, последовательно изменяющимся
# от $x_{min}$ до $x_{max}$ с шагом $step$. Выполните задание для $y(x)=sin(x)^4$, $x_{min}=1$, $x_{max}=5$, $step=0.05$

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib widget

# %%
def y(x):
    return np.sin(x)**4

# %%
x_min=1
x_max=5
step=0.05

# %%
x_array=np.arange(x_min,x_max,step)
y_array=y(x_array)

# %%
matrix0=[x_array,y_array]
matrix=np.transpose(matrix0)

# %%
fig1=plt.figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
y_min, y_max=np.min(y_array),np.max(y_array)
ax1=plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
# Out:
# (0.5, 5.5, -0.499999995004082, 1.4996930655910048)

# %%
line1, = ax1.plot([],[],'b',lw=5)
print(type(line1))
line1.get_xdata(),line1.get_ydata(),
# Out:
# <class 'matplotlib.lines.Line2D'>
# (array([], dtype=float64), array([], dtype=float64))

# %%
def at_frame1(point):
    """добавляет к объекту line1 точку с координатами (point[0],point[1])

 Arguments : 
 point : массив из двух элементов

 Returns : None
 """
    x_coord,y_coord=list(line1.get_xdata()),list(line1.get_ydata())
    x_coord.append(point[0])
    y_coord.append(point[1])
    line1.set_data(x_coord,y_coord)
# ?line1.set_data
# Out:
# Signature: line1.set_data(*args)
# Docstring:
# Set the x and y data.
#
# Parameters
# ----------
# *args : (2, N) array or two 1D arrays
#
# See Also
# --------
# set_xdata
# set_ydata
# File:      d:\000_mmf_bsu\program files\0_anaconda\envs\newenvy\lib\site-packages\matplotlib\lines.py
# Type:      method

# %%
# ?at_frame1
# Out:
# Signature: at_frame1(point)
# Docstring:
# добавляет к объекту line1 точку с координатами (point[0],point[1])
#
# Arguments :
# point : массив из двух элементов
#
# Returns : None
# File:      c:\users\alex2\appdata\local\temp\ipykernel_10752\1201468896.py
# Type:      function

# %%
help(at_frame1)
# Out:
# Help on function at_frame1 in module __main__:
#
# at_frame1(point)
#     добавляет к объекту line1 точку с координатами (point[0],point[1])
#
#     Arguments :
#     point : массив из двух элементов
#
#     Returns : None

# %%
print(at_frame1.__doc__)
# Out:
# добавляет к объекту line1 точку с координатами (point[0],point[1])
#
#  Arguments :
#  point : массив из двух элементов
#
#  Returns : None

# %%
fig1=plt.figure()
ax1=plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
line1,=ax1.plot([],[],'b')
FuncAnimation(fig1, at_frame1, frames=matrix,repeat=False,interval=15)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# ### 3.1B
# $\color{red}\text{Создайте анолгичную анимацию}$ построения графика параметрически
# заданной функции $x=x(t)$, $y=y(t)$ по значениям $t$, последовательно
# изменяющимся от $t_{min}$ до $t_{max}$ с шагом $step$. Выполните задание для функции из Задания 1.4 в Лб1, согласно Вашему варианту. Значения и выберите самостоятельно с учетом непрерывности параметрической функции на выбранном диапазоне, $step=\frac{t_{max}-t_{min}}{100}$

# %%
def x(t):
    return np.log(np.sqrt((1 - t)/(1+t)))
def y(t):
    return np.sqrt(1-t**2)

# %%
t_min=-0.99
t_max=0.99
step1=(t_max-t_min)/100
t_array1=np.arange(t_min,t_max,step1)

# %%
x_array1=x(t_array1)
y_array1=y(t_array1)
matrix1=np.transpose([x_array1,y_array1])

# %%
fig0=plt.figure()
x_min1,x_max1=np.min(x_array1),np.max(x_array1)
y_min1,y_max1=np.min(y_array1),np.max(y_array1)
ax0=plt.axes()
plt.axis([x_min1-0.5, x_max1+0.5, y_min1-0.5, y_max1+0.5])
# Out:
# (-3.1466524123624464, 3.1466524123622457, -0.358932640203369, 1.5)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
line0, = ax0.plot([],[],'g')
line0.get_ydata()
# Out:
# array([], dtype=float64)

# %%
def at_frame0(point):
 """добавляет к объекту line3 точку с координатами (point[0],point[1])

 Arguments :
 point : массив из двух элементов

 Returns : None
 """
 x_coord = list(line0.get_xdata())
 y_coord = list(line0.get_ydata())

 x_coord.append(point[0])
 y_coord.append(point[1])

 line0.set_data(x_coord, y_coord)

# %%
fig0=plt.figure()
ax1=plt.axes()
plt.axis([x_min1-0.5, x_max1+0.5, y_min1-0.5, y_max1+0.5])
line0,=ax0.plot([],[],'g')
FuncAnimation(fig0, at_frame0, frames=matrix1,repeat=False,interval=15)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# ## Задание 3.2. Движение точки по линии на плоскости

# %% [markdown]
# $\color{red}\text{Создайте анимацию}$ движения точки по графику функции $x=x(t)$, $y=y(t)$ по значениям $t$, последовательно
# изменяющимся от $t_{min}$ до $t_{max}$ с шагом $step$. Функция $x=x(t)$, $y=y(t)$ и значения переменных $t_{min}$, $t_{max}$, $step$ задаются такими же, как и при выполнении Задания 3.1b

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
line1, = ax2.plot(x_array, y_array,'b') # объект для графика функции
line2, = ax2.plot([], [],'go') # объект для точки
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def at_frame2(point):
 """задает объект line2 точкой с координатами (point[0],point[1])

 Arguments :

 point : массив из двух элементов

 Returns : None
 """
 line2.set_data([point[0]],[point[1]])

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])

def init():
    # создает начальное состояние графической области
    global line2 
    line1, = ax2.plot(x_array, y_array,'b') # объект для графика функции
    line2, = ax2.plot([], [],'go') # объект для точки
    plt.legend([r'$y(x) = \sin(x)^4$','Movable point'])
FuncAnimation(fig2,at_frame2,frames=matrix,init_func=init,repeat=False,interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# $\color{red}\text{Создайте анолгичную анимацию}$ для функции $x=x(t)$, $y=y(t)$ из Задания 3.1b

# %%
fig00 = plt.figure()
ax00 = plt.axes()
plt.axis([x_min1-0.5, x_max1+0.5, y_min1-0.5, y_max1+0.5])
line0, = ax00.plot(x_array1, y_array1,'g') # объект для графика функции
line00, = ax00.plot([], [],'mo') # объект для точки
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def at_frame00(point):
 """задает объект line00 точкой с координатами (point[0],point[1])

 Arguments :
 point : массив из двух элементов

 Returns : None
 """
 line00.set_data([point[0]],[point[1]])

# %%
fig00 = plt.figure()
ax00 = plt.axes()
plt.axis([x_min1-0.5, x_max1+0.5, y_min1-0.5, y_max1+0.5])

def init0():
    # создает начальное состояние графической области
    global line00
    line0, = ax00.plot(x_array1, y_array1,'g') # объект для графика функции
    line00, = ax00.plot([], [],'mo') # объект для точки
    plt.legend([r'x(t) = \log.e(\sqrt((1-t)/(1+t)); y(t) = \sqrt(1-t^2)','Movable point'])
FuncAnimation(fig00,at_frame00,frames=matrix1,init_func=init0,repeat=False,interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# ## Задание 3.3. Движение секущей прямой к заданной линии на плоскости (версия 1)

# %% [markdown]
# Линия на плоскости задана графиком параметрической функции $x=x(t)$, $y=y(t)$, для $t\in [t_{min},t_{max}]$ из Задания 3.1b. Начальная точка $A$ с координатами $(x(t_{min}),y(t_{min}))$ является неподвижной точкой. Точка $B$ движется последовательно по линии от конечной точки кривой с координатами $(x(t_{max}),y(t_{max}))$ к неподвижной точке $A$

# %% [markdown]
# $\color{red}\text{Создайте анимацию}$ движения секущей прямой, проходящей через точки $A$ и $B$ до момента совпадении координат точек $A$ и $B$, когда секущая прямая становится касательной прямой к заданной линии в начальной точке $A$.

# %%
fig3 = plt.figure()
ax3 = plt.axes()
plt.axis([x_min-1, x_max+1, y_min-1, y_max+1])
def init():
 """cоздает начальное состояние графической области перед началом анимации и
 global point_B, secant_line # переменные сделаны глобальными, чтобы они были"""

 curve, = ax3.plot(x_array, y_array,'b') # графический объект для исходной фу

 A = np.array([x_array[0], y_array[0]])
 point_A, = ax3.plot(A[0],A[1],'ro') # графический объект для неподвижной точ

 B = np.array([x_array[-1], y_array[-1]])
 point_B, = ax3.plot(B[0],B[1],'go') # графический объект для подвижной точки

 secant_p = [A + (B - A)*t for t in [-2, 2]] # две точки секущей прямой, прох
 secant_p = np.array(secant_p)
 secant_line, = ax3.plot(secant_p[:,0], secant_p[:,1],'g') # графический объе

 plt.legend([r'$y(x) = \sin(x)^4$','Unmovable point A','Мovable point B','Sec'])
def at_frame3(point):
 """do ...

 Arguments :

 point : массив из двух элементов, задающий координаты подвижной точки

 Returns : None
 """
 ...

FuncAnimation(fig3, at_frame3, frames=matrix[::-1], init_func=init, repeat=False, interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ...
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\ipympl\backend_nbagg.py:279, in Canvas._handle_message(self, object, content, buffers)
#     276     self.manager.handle_json(content)
#     278 else:
# --> 279     self.manager.handle_json(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:264, in FigureCanvasWebAggCore.handle_event(self, event)
#     261 e_type = event['type']
#     262 handler = getattr(self, f'handle_{e_type}',
#     263                   self.handle_unknown_event)
# --> 264 return handler(event)
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:288, in FigureCanvasWebAggCore._handle_mouse(self, event)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
# --> 288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
#     295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# File d:\000_MMF_BSU\Program files\0_Anaconda\envs\newenvy\lib\site-packages\matplotlib\backends\backend_webagg_core.py:295, in <setcomp>(.0)
#     286 e_type = event['type']
#     287 button = event['button'] + 1  # JS numbers off by 1 compared to mpl.
#     288 buttons = {  # JS ordering different compared to mpl.
#     289     button for button, mask in [
#     290         (MouseButton.LEFT, 1),
#     291         (MouseButton.RIGHT, 2),
#     292         (MouseButton.MIDDLE, 4),
#     293         (MouseButton.BACK, 8),
#     294         (MouseButton.FORWARD, 16),
# --> 295     ] if event['buttons'] & mask  # State *after* press/release.
#     296 }
#     297 modifiers = event['modifiers']
#     298 guiEvent = event.get('guiEvent')
#
# KeyError: 'buttons'

# %%
plt.close('all')

# %% [markdown]
# $\color{red}\text{Напишите}$ пользовательскую функцию ``at_frame3(t)``, которая будет вызываться в каждом кадре анимации, полагая, что аргумент ``point`` является массивом координат подвижной точки $B$. $\color{red}\text{Напишите}$ строки документации для пользовательской функции ``at_frame3``

# %% [markdown]
# ## Задание 3.4. Движение секущей прямой к заданной линии на плоскости (версия 2)

# %% [markdown]
# Линия на плоскости задана графиком параметрической функции $x=x(t)$, $y=y(t)$, для $t\in [t_{min},t_{max}]$ из Задания 3.1b. Начальная точка $A$ с координатами $(x(t_{min}),y(t_{min}))$ является неподвижной точкой. Точка $B$ движется последовательно по линии от конечной точки кривой с координатами $(x(t_{max}),y(t_{max}))$ к неподвижной точке $A$

# %% [markdown]
# $\color{red}\text{Создайте анимацию}$ движения секущей прямой, проходящей через точки $A$ и $B$ до момента совпадении координат точек $A$ и $B$, когда секущая прямая становится касательной прямой к заданной линии в конечной точке $B$, необходимое для построения касательной прямой,
# осуществите с помощью возможностей модуля ``sympy`` . Касательную прямую изобразите красным цветом.
