# %% [markdown]
# # Лабароторная работа 3

# %% [markdown]
# # Анимация движения секущей прямой к заданной линии на плоскости

# %% [markdown]
# Федоренко Алексей Жанович, 13.03.2025

# %%
from matplotlib.animation import FuncAnimation

# %% [markdown]
# ## Задание 3.1 Анимированное построение линии на плоскости

# %% [markdown]
# ### 3.1A
# $\color{red}\text{Создайте анимацию}$ построения графика некоторой явно заданной
# аналитической функции $y=y(x)$ по значениям $x$, последовательно изменяющимся
# от $x_{min}$ до $x_{max}$ с шагом $step$. Выполните задание для $y(x)=sin(x)^4$, $x_{min}=1$, $x_{max}=5$, $step=0.05$

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
# %matplotlib widget

# %%
def y(x):
    return np.sin(x)**4

# %%
x_min=1
x_max=5
step=0.05

# %%
x_array=np.arange(x_min,x_max,step)
y_array=y(x_array)

# %%
matrix0=[x_array,y_array]
matrix=np.transpose(matrix0)

# %%
fig1=plt.figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
y_min, y_max=np.min(y_array),np.max(y_array)
ax1=plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
# Out:
# (0.5, 5.5, -0.499999995004082, 1.4996930655910048)

# %%
line1, = ax1.plot([],[],'b',lw=5)
print(type(line1))
line1.get_xdata(),line1.get_ydata(),
# Out:
# <class 'matplotlib.lines.Line2D'>
# (array([], dtype=float64), array([], dtype=float64))

# %%
def at_frame1(point):
    """do: добавляет к объекту line1 точку с координатами (point[0],point[1])

 Arguments : 
 point : массив из двух элементов

 Returns : None
 """
    x_coord,y_coord=list(line1.get_xdata()),list(line1.get_ydata())
    x_coord.append(point[0])
    y_coord.append(point[1])
    line1.set_data(x_coord,y_coord)
# ?line1.set_data
# Out:
# Signature: line1.set_data(*args)
# Docstring:
# Set the x and y data.
#
# Parameters
# ----------
# *args : (2, N) array or two 1D arrays
#
# See Also
# --------
# set_xdata
# set_ydata
# File:      d:\000_programm_files\00_anaconda_python\envs\anaconda_env\lib\site-packages\matplotlib\lines.py
# Type:      method

# %%
# ?at_frame1
# Out:
# Signature: at_frame1(point)
# Docstring:
# do: добавляет к объекту line1 точку с координатами (point[0],point[1])
#
# Arguments :
# point : массив из двух элементов
#
# Returns : None
# File:      c:\users\alex2\appdata\local\temp\ipykernel_6624\905773013.py
# Type:      function

# %%
help(at_frame1)
# Out:
# Help on function at_frame1 in module __main__:
#
# at_frame1(point)
#     do: добавляет к объекту line1 точку с координатами (point[0],point[1])
#
#     Arguments :
#     point : массив из двух элементов
#
#     Returns : None

# %%
print(at_frame1.__doc__)
# Out:
# do: добавляет к объекту line1 точку с координатами (point[0],point[1])
#
#  Arguments :
#  point : массив из двух элементов
#
#  Returns : None

# %%
fig1=plt.figure()
ax1=plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
line1,=ax1.plot([],[],'b')
plt.legend([r'$ y(x) =\sin(x)^4$'])
FuncAnimation(fig1, at_frame1, frames=matrix,repeat=False,interval=50)
# Out:
# findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmr10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmtt10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmmi10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmb10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmss10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmex10'] not found. Falling back to DejaVu Sans.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# ### 3.1B
# $\color{red}\text{Создайте анолгичную анимацию}$ построения графика параметрически
# заданной функции $x=x(t)$, $y=y(t)$ по значениям $t$, последовательно
# изменяющимся от $t_{min}$ до $t_{max}$ с шагом $step$. Выполните задание для функции из Задания 1.4 в Лб1, согласно Вашему варианту. Значения и выберите самостоятельно с учетом непрерывности параметрической функции на выбранном диапазоне, $step=\frac{t_{max}-t_{min}}{100}$

# %%
def x(t):
    return np.log(np.sqrt((1 - t)/(1 + t)))
def y(t):
    return np.sqrt(1 - t**2)

# %%
t_min=-0.99
t_max=0.99
step0=(t_max-t_min)/100
t_array0=np.arange(t_min,t_max,step0)

# %%
x_array0=x(t_array0)
y_array0=y(t_array0)
matrix0=np.transpose([x_array0,y_array0])

# %%
fig0=plt.figure()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_min0,x_max0=np.min(x_array0),np.max(x_array0)
y_min0,y_max0=np.min(y_array0),np.max(y_array0)
ax0=plt.axes()
plt.axis([x_min0-0.5, x_max0+0.5, y_min0-0.5, y_max0+0.5])
# Out:
# (-3.1466524123624464, 3.1466524123622457, -0.358932640203369, 1.5)

# %%
line0, = ax0.plot([],[],'g')
line0.get_ydata()
# Out:
# array([], dtype=float64)

# %%
def at_frame0(point):
 """do: добавляет к объекту line3 точку с координатами (point[0],point[1])

 Arguments :
 point : массив из двух элементов

 Returns : None
 """
 x_coord = list(line0.get_xdata())
 y_coord = list(line0.get_ydata())

 x_coord.append(point[0])
 y_coord.append(point[1])

 line0.set_data(x_coord, y_coord)

# %%
fig0=plt.figure()
ax0=plt.axes()
plt.axis([x_min0-0.5, x_max0+0.5, y_min0-0.5, y_max0+0.5])
line0 , = ax0.plot([],[],'g')
plt.legend([r'$x(t) = \ln\sqrt{\frac{1-t}{1+t}}, y(t) = \sqrt{1-t^2}$'])
FuncAnimation(fig0, at_frame0, frames=matrix0,repeat=False,interval=50)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# ## Задание 3.2. Движение точки по линии на плоскости

# %% [markdown]
# $\color{red}\text{Создайте анимацию}$ движения точки по графику функции $x=x(t)$, $y=y(t)$ по значениям $t$, последовательно
# изменяющимся от $t_{min}$ до $t_{max}$ с шагом $step$. Функция $x=x(t)$, $y=y(t)$ и значения переменных $t_{min}$, $t_{max}$, $step$ задаются такими же, как и при выполнении Задания 3.1b

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])
line1, = ax2.plot(x_array, y_array,'b') #график функции
line2, = ax2.plot([], [],'go') #точкa
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def at_frame2(point):
 """do: задает объект line2 точкой с координатами (point[0],point[1])

 Arguments :
 point : массив из двух элементов

 Returns : None
 """
 line2.set_data([point[0]],[point[1]])

# %%
fig2 = plt.figure()
ax2 = plt.axes()
plt.axis([x_min-0.5, x_max+0.5, y_min-0.5, y_max+0.5])

def init():
    #начальное состояние графической области
    global line2 
    line1, = ax2.plot(x_array, y_array,'b') #график функции
    line2, = ax2.plot([], [],'go') #точкa
    plt.legend([r'$y(x) = \sin(x)^4$','Movable point'])
FuncAnimation(fig2,at_frame2,frames=matrix,init_func=init,repeat=False,interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# $\color{red}\text{Создайте анолгичную анимацию}$ для функции $x=x(t)$, $y=y(t)$ из Задания 3.1b

# %%
fig00 = plt.figure()
ax00 = plt.axes()
plt.axis([x_min0-0.5, x_max0+0.5, y_min0-0.5, y_max0+0.5])
line0, = ax00.plot(x_array0, y_array0,'g') # объект для графика функции
line00, = ax00.plot([], [],'mo') # объект для точки
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def at_frame00(point):
 """do: задает объект line00 точкой с координатами (point[0],point[1])

 Arguments :
 point : массив из двух элементов

 Returns : None
 """
 line00.set_data([point[0]],[point[1]])

# %%
fig00 = plt.figure()
ax00 = plt.axes()
plt.axis([x_min0-0.5, x_max0+0.5, y_min0-0.5, y_max0+0.5])

def init0():
    # создает начальное состояние графической области
    global line00
    line0, = ax00.plot(x_array0, y_array0,'g') # объект для графика функции
    line00, = ax00.plot([], [],'mo') # объект для точки
    plt.legend([r'$x(t) = \ln\sqrt{\frac{1-t}{1+t}}, y(t) = \sqrt{1-t^2}$','Movable point'])
FuncAnimation(fig00,at_frame00,frames=matrix0,init_func=init0,repeat=False,interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# ## Задание 3.3. Движение секущей прямой к заданной линии на плоскости (версия 1)

# %% [markdown]
# Линия на плоскости задана графиком параметрической функции $x=x(t)$, $y=y(t)$, для $t\in [t_{min},t_{max}]$ из Задания 3.1b. Начальная точка $A$ с координатами $(x(t_{min}),y(t_{min}))$ является неподвижной точкой. Точка $B$ движется последовательно по линии от конечной точки кривой с координатами $(x(t_{max}),y(t_{max}))$ к неподвижной точке $A$

# %% [markdown]
# $\color{red}\text{Создайте анимацию}$ движения секущей прямой, проходящей через точки $A$ и $B$ до момента совпадении координат точек $A$ и $B$, когда секущая прямая становится касательной прямой к заданной линии в начальной точке $A$.

# %% [markdown]
# $\color{red}\text{Напишите}$ пользовательскую функцию ``at_frame3(t)``, которая будет вызываться в каждом кадре анимации, полагая, что аргумент ``point`` является массивом координат подвижной точки $B$. $\color{red}\text{Напишите}$ строки документации для пользовательской функции ``at_frame3``

# %%
s=np.array([1,2])
s,step
# Out:
# (array([1, 2]), 0.05)

# %%
fig3 = plt.figure()
ax3 = plt.axes()
plt.axis([x_min-1, x_max+1, y_min-1, y_max+1])

def init():
 """cоздает начальное состояние графической области перед началом анимации и
 global point_B, secant_line # переменные сделаны глобальными, чтобы они были были доступны для изменения"""
 global point_B, secant_line
 curve, = ax3.plot(x_array, y_array,'b') # графический объект для исходной функции

 A = np.array([x_array[0], y_array[0]])
 point_A, = ax3.plot(A[0],A[1],'ro') # графический объект для неподвижной точки А

 B = np.array([x_array[-1], y_array[-1]])
 point_B, = ax3.plot(B[0],B[1],'go') # графический объект для подвижной точки В

 secant_p = [A + (B - A)*t for t in [-2, 2]] # две точки секущей прямой, проходящая точки A и B, формула параметрического уравнения секущей
 secant_p = np.array(secant_p)
 secant_line, = ax3.plot(secant_p[:,0], secant_p[:,1],'g') # графический объект для секущей прямой

 plt.legend([r'$y(x) = \sin(x)^4$','Unmovable point A','Мovable point B','Secant line through A and B'])
    
def at_frame3(point):
 """do: Обновляет координаты точки B и секущую secant

 Arguments :
 point : массив из двух элементов, задающий координаты подвижной точки B

 Returns : None
 """
    
 A = np.array([x_array[0], y_array[0]])
 B = np.array(point)
 if B[0]-A[0]<step:
     k=4*(np.sin(A[0])**3)*np.cos(A[0])
     touch,=ax3.plot([4*(np.sin(A[0])**3)*np.cos(A[0])*(t-A[0])+np.sin(A[0])**4 for t in [-10, 10]],'r') 

 secant_p = [A + (B - A)*t for t in [-2, 2]]
 secant_p = np.array(secant_p)
 secant_line.set_data(secant_p[:,0], secant_p[:,1])
 point_B.set_data([point[0]],[point[1]])
    
 
 


FuncAnimation(fig3, at_frame3, frames=matrix[::-1], init_func=init, repeat=False, interval=30)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %%
fig4 = plt.figure()
ax4 = plt.axes()
plt.axis([x_min0-1, x_max0+1, y_min0-1, y_max0+1])

def init1():
 """cоздает начальное состояние графической области перед началом анимации и
 global point_B1, secant_line1 # переменные сделаны глобальными, чтобы они были были доступны для изменения"""
 global point_B1, secant_line1
 curve1, = ax4.plot(x_array0, y_array0,'b') # графический объект для исходной функции

 A1 = np.array([x_array0[0], y_array0[0]])
 point_A1, = ax4.plot(A1[0],A1[1],'ro') # графический объект для неподвижной точки А

 B1 = np.array([x_array0[-1], y_array0[-1]])
 point_B1, = ax4.plot(B1[0],B1[1],'go') # графический объект для подвижной точки В

 secant_p1 = [A1 + (B1 - A1)*t for t in [-2, 2]] # две точки секущей прямой, проходящая точки A и B, формула параметрического уравнения секущей
 secant_p1 = np.array(secant_p1)
 secant_line1, = ax4.plot(secant_p1[:,0], secant_p1[:,1],'g') # графический объект для секущей прямой

 plt.legend([r'$x(t) = \ln\sqrt{\frac{1-t}{1+t}}, y(t) = \sqrt{1-t^2}$','Unmovable point A','Мovable point B','Secant line through A and B'])

def at_frame4(point):
 """do: Обновляет координаты точки B и секущую secant

 Arguments :
 point : массив из двух элементов, задающий координаты подвижной точки B

 Returns : None
 """
 A1 = np.array([x_array0[0], y_array0[0]])
 B1 = np.array(point)
 """if A1[0]-B1[0]<step:
        touch, = ax4.plot([(-1*(1-1**2)**0.5)*(t-A[0])+A[1] for t in [-2,2]], 'r')"""
 secant_p1 = [A1 + (B1 - A1)*t for t in [-2, 2]]
 secant_p1 = np.array(secant_p1)
    
 point_B1.set_data([point[0]],[point[1]])
 secant_line1.set_data(secant_p1[:,0], secant_p1[:,1])

FuncAnimation(fig4, at_frame4, frames=matrix0[::-1], init_func=init1, repeat=False, interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close('all')

# %% [markdown]
# ## Задание 3.4. Движение секущей прямой к заданной линии на плоскости (версия 2)

# %% [markdown]
# Линия на плоскости задана графиком параметрической функции $x=x(t)$, $y=y(t)$, для $t\in [t_{min},t_{max}]$ из Задания 3.1b. Начальная точка $A$ с координатами $(x(t_{min}),y(t_{min}))$ является подвижной точкой на заданной линии. Точка $B$ с координатами $(x(t_{max}),y(t_{max}))$ является неподвижной точкой. Точка $A$ движется последовательно по кривой до неподвижной точки $B$.

# %% [markdown]
# $\color{red}\text{Создайте анимацию}$ движения секущей прямой, проходящей через точки $A$ и $B$ до момента совпадении координат точек $A$ и $B$, когда секущая прямая становится касательной прямой к заданной линии в конечной точке $B$, необходимое для построения касательной прямой, осуществите с помощью возможностей модуля ``sympy`` . Касательную прямую изобразите красным цветом.

# %%
import sympy
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 import sympy
#
# ModuleNotFoundError: No module named 'sympy'

# %%
fig5 = plt.figure()
ax5 = plt.axes()
plt.axis([x_min0-1, x_max0+1, y_min0-1, y_max0+1])

def init2():
    """Создает начальное состояние графической области перед началом анимации."""
    global point_A2, secant_line2
    curve1, = ax5.plot(x_array0, y_array0, 'b')
    
    B2 = np.array([x_array0[-1], y_array0[-1]])
    point_B2, = ax5.plot(B2[0], B2[1], 'go') 
    A2 = np.array([x_array0[0], y_array0[0]])
    point_A2, = ax5.plot(A2[0], A2[1], 'ro')  
    secant_p2 = [A2 + (B2 - A2)*t for t in [-2, 2]]
    secant_p2 = np.array(secant_p2)
    secant_line2, = ax5.plot(secant_p2[:, 0], secant_p2[:, 1], 'g')
    
    plt.legend([r'$x(t) = \ln\sqrt{\frac{1-t}{1+t}},\ y(t) = \sqrt{1-t^2}$',
                'Fixed point B', 'Moving point A', 'Secant line through A and B'])

def at_frame5(point):
    """Обновляет координаты точки A и секущую прямую через A и неподвижную точку B.
    
    Аргументы:
        point : массив из двух элементов, задающий новые координаты точки A
    """
    A2 = np.array(point)
    B2 = np.array([x_array0[-1], y_array0[-1]])
    
    secant_p2 = [A2 + (B2 - A2)*t for t in [-2, 2]]
    secant_p2 = np.array(secant_p2)
    
    point_A2.set_data([A2[0]], [A2[1]])
    secant_line2.set_data(secant_p2[:, 0], secant_p2[:, 1])


FuncAnimation(fig5, at_frame5, frames=matrix0, init_func=init2, repeat=False, interval=20)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
